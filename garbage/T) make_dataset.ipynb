# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./data/train_input/CASE_01.csv")

# %%
df
# Out:
#      DAT obs_time    내부온도관측치    내부습도관측치      co2관측치     ec관측치  시간당분무량  \
# 0      0    00:00  25.300000  81.835000  536.016667  1.407439     0.0
# 1      0    01:00  25.680357  81.264286  528.696429  1.409003   126.0
# 2      0    02:00  25.273333  81.471666  532.833333  1.406913     0.0
# 3      0    03:00  25.355000  81.398334  545.566667  1.406689   126.0
# 4      0    04:00  25.391667  81.483333  558.583333  1.411070     0.0
# ..   ...      ...        ...        ...         ...       ...     ...
# 667   27    19:00  30.880000  82.255000  464.433333  0.000000   252.0
# 668   27    20:00  29.068333  82.506667  534.633333  0.000000   126.0
# 669   27    21:00  28.246667  82.835000  563.433333  0.000000     0.0
# 670   27    22:00  28.005000  82.850000  577.150000  0.000000   126.0
# 671   27    23:00  27.868333  82.453333  588.616667  0.000000     0.0
#
#      일간누적분무량   시간당백색광량   일간누적백색광량  시간당적색광량   일간누적적색광량  시간당청색광량  일간누적청색광량  \
# 0       0.00      0.00       0.00    0.000      0.000        0         0
# 1     126.00      0.00       0.00    0.000      0.000        0         0
# 2     126.00      0.00       0.00    0.000      0.000        0         0
# 3     252.00      0.00       0.00    0.000      0.000        0         0
# 4     252.00      0.00       0.00    0.000      0.000        0         0
# ..       ...       ...        ...      ...        ...      ...       ...
# 667  3638.54  18255.19  254644.43  976.332  13619.004        0         0
# 668  3764.54    618.82  255263.25   33.096  13652.100        0         0
# 669  3764.54      0.00  255263.25    0.000  13652.100        0         0
# 670  3890.54      0.00  255263.25    0.000  13652.100        0         0
# 671  3890.54      0.00  255263.25    0.000  13652.100        0         0
#
#         시간당총광량     일간누적총광량
# 0        0.000       0.000
# 1        0.000       0.000
# 2        0.000       0.000
# 3        0.000       0.000
# 4        0.000       0.000
# ..         ...         ...
# 667  19231.522  268263.434
# 668    651.916  268915.350
# 669      0.000  268915.350
# 670      0.000  268915.350
# 671      0.000  268915.350
#
# [672 rows x 16 columns]

# %%
import statsmodels.api as sm

# %%
sm.tsa.seasonal_decompose(df, model='additive').plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\mb_job\project\Competition\Lettuce-Growth-Environment-Prediction\T) make_dataset.ipynb 셀 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/mb_job/project/Competition/Lettuce-Growth-Environment-Prediction/T%29%20make_dataset.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> sm.tsa.seasonal_decompose(df, model='additive').plot()
#
# File c:\Python\Python38\lib\site-packages\statsmodels\tsa\seasonal.py:142, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     139 if period is None:
#     140     pfreq = getattr(getattr(x, "index", None), "inferred_freq", None)
# --> 142 x = array_like(x, "x", maxdim=2)
#     143 nobs = len(x)
#     145 if not np.all(np.isfinite(x)):
#
# File c:\Python\Python38\lib\site-packages\statsmodels\tools\validation\validation.py:135, in array_like(obj, name, dtype, ndim, maxdim, shape, order, contiguous, optional)
#     133 if optional and obj is None:
#     134     return None
# --> 135 arr = np.asarray(obj, dtype=dtype, order=order)
#     136 if maxdim is not None:
#     137     if arr.ndim > maxdim:
#
# File c:\Python\Python38\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: '00:00'
