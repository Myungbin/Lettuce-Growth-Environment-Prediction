# %%
from sdv.tabular import CTGAN
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('./data/train_all.csv')
train = train.drop(['predicted_weight_g'], axis=1)
model = CTGAN()

# %%
model.fit(train)

# %%
new_data = model.sample(num_rows=700)

# %%
new_data
# Out:
#      DAT  obs_time    내부온도관측치    내부습도관측치  co2관측치  ec관측치  시간당분무량  일간누적분무량  \
# 0     17         5  23.796179  79.661888   899.0    3.0    58.0   4282.0
# 1     27         0  20.407084  77.430432   492.0    2.0     NaN      0.0
# 2      1        15  22.848352  60.075379   532.0    1.0     3.0   6526.0
# 3      3         1  31.290922  59.107217   415.0    4.0   770.0   1059.0
# 4      2        13        NaN  44.351106   671.0    1.0   140.0   1011.0
# ..   ...       ...        ...        ...     ...    ...     ...      ...
# 695    3         0  22.128954  61.218703   556.0    1.0     4.0    185.0
# 696    7        16  27.118444  81.161920   450.0    0.0   260.0   1471.0
# 697   13         4  23.567695  57.728057   619.0    1.0     2.0    733.0
# 698   22         8  26.540545  57.063824   453.0    0.0     NaN  21644.0
# 699   21         9  26.370311  70.585637   387.0    1.0  1408.0  18235.0
#
#      시간당백색광량  일간누적백색광량  시간당적색광량  일간누적적색광량  시간당청색광량  일간누적청색광량  시간당총광량  \
# ...
